# %%
print("****** Welcome to the Coder's ATM ********")
chance=3
restart=('Y')
balance=10000
while chance>=0:
    pin=int(input("Enter your pin Here"))
    if pin==(9999):
        print("You entered pin correctly")
        print("Press 1 for your Account Balance ")
        print("Press 2 to Make a Withdrawl ")
        print("Press 3 To Pay ")
        print("Press 4 Return Card ")
        while restart not in ('n','No','N','NO','no'):
            print("Press 1 for your Account Balance ")
            print("Press 2 to Make a Withdraw ")
            print("Press 3 To Pay ")
            print("Press 4 Return Card ")
            option=int(input("What would you like to choose ? : "))
            if option==1:
                print("Your account balance is : ",balance)
                restart=input("would you like to go back ? ")
                if restart not in ('n','No','N','NO','no'):
                    print("Thanks for using our service , We are Happy with You ")
                    break
            elif option==2:
                option2=('Y')
                withdrawl=float(input("How much money would you like to withdraw"))
                if withdrawl in range(1,10000):
                    balance=balance-withdrawl
                    print("\nNow your account balance is ",balance)
                    restart=input("would you like to go back ? ")
                    if restart in ('n','No','N','NO','no'):
                        print("Thanks for using our service , We are Happy with You ")
                        break
                elif withdrawl!=range(1,1000):
                    print("Invalid amount ,Please try again ")
                    restart=('Y')
                elif withdrawl==1:
                    withdrawl=float(input("Please enter desired amount"))
                    
            elif option==3:
                pay_in=float(input("How much money would you like to pay in Account ? "))
                balance=balance+pay_in
                print("Now your updated Balance is ",balance)
                restart=input("would you like to go back ? ")
                if restart not in ('n','No','N','NO','no'):
                    print("Thanks for using our service , We are Happy with You ")
                    break
            elif option==4:
                print("please wait , We are processing...")
                print("please wait while your card is Returned...\n")
                print("Thanks for your service")
                break
            else:
                print("please enter a correct nunmber :")
                restart=('Y')
    elif pin !=('9999'):
        print("your pin is incorrect ....please try again latter")
        chance=chance-1
        if chance==0:
            print("No more tries")
            break
# Out:
# ****** Welcome to the Coder's ATM ********
# Enter your pin Here9999
# You entered pin correctly
# Press 1 for your Account Balance
# Press 2 to Make a Withdrawl
# Press 3 To Pay
# Press 4 Return Card
# Press 1 for your Account Balance
# Press 2 to Make a Withdraw
# Press 3 To Pay
# Press 4 Return Card
# What would you like to choose ? : 1
# Your account balance is :  10000
# would you like to go back ? Y
# Thanks for using our service , We are Happy with You
# Enter your pin Here9999
# You entered pin correctly
# Press 1 for your Account Balance
# Press 2 to Make a Withdrawl
# Press 3 To Pay
# Press 4 Return Card
# Press 1 for your Account Balance
# Press 2 to Make a Withdraw
# Press 3 To Pay
# Press 4 Return Card
# What would you like to choose ? : 2
# How much money would you like to withdraw3000
#
# Now your account balance is  7000.0
# would you like to go back ? Y
# Press 1 for your Account Balance
# Press 2 to Make a Withdraw
# Press 3 To Pay
# Press 4 Return Card
# ...
